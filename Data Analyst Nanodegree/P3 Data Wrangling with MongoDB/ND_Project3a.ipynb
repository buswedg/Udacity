# %%
import codecs
import collections
import json
import os
import pprint
import pymongo
import re

import xml.etree.ElementTree as ET

osmfilenm = 'data/perth_australia.osm'

# %%
# Count tags

def count_tags(filename):
    tags = defaultdict(int)

    for event, node in ET.iterparse(filename):
        if event == 'end': 
            tags[node.tag] += 1
        node.clear()             
    return tags


count_tags(osmfilenm)
# Out:
# defaultdict(<type 'int'>, {'node': 1000411, 'nd': 1236818, 'bounds': 1, 'member': 10565, 'tag': 368028, 'relation': 1505, 'way': 123824, 'osm': 1})

# %%
# Count character types

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        k_value = element.attrib['k']
        if lower.search(k_value) is not None:
            keys['lower'] += 1
        elif lower_colon.search(k_value) is not None:
            keys['lower_colon'] += 1
        elif problemchars.search(k_value) is not None:
            keys["problemchars"] += 1
        else:
            keys['other'] += 1

    return keys


def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys


process_map(osmfilenm)
# Out:
# {'lower': 328169, 'lower_colon': 39185, 'other': 674, 'problemchars': 0}

# %%
# Audit street names

street_type_re = re.compile(r'\S+\.?$', re.IGNORECASE)
street_types = defaultdict(int)

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()

        street_types[street_type] += 1

        
def print_sorted_dict(d):
    keys = d.keys()
    keys = sorted(keys, key=lambda s: s.lower())
    for k in keys:
        v = d[k]
        print "%s: %d" % (k, v) 

        
def is_street_name(elem):
    return (elem.tag == "tag") and (elem.attrib['k'] == "addr:street")


def audit(filename):
    osm_file = open(filename, "r")
    for event, elem in ET.iterparse(osm_file):
        if is_street_name(elem):
            audit_street_type(street_types, elem.attrib['v'])   
    print_sorted_dict(street_types)

    
audit(osmfilenm)
# Out:
# (LANEWAY): 1
# Ave: 6
# Avenue: 328
# Avenuet: 1
# Beaufort: 1
# Boulevard: 185
# Boulevarde: 23
# Broadway: 2
# Circle: 62
# Circuit: 31
# Close: 129
# Corner: 9
# Court: 304
# Courtyard: 12
# Cove: 18
# Cres: 2
# Crescent: 108
# Cross: 153
# Crossway: 21
# Crs: 1
# CRT: 7
# Crt: 8
# Ct: 2
# Dale: 9
# Drive: 391
# drive: 1
# E/ENT: 3
# E/Ent: 1
# East: 7
# Edge: 8
# Elbow: 55
# Entrance: 153
# ENTRANCE: 1
# Esplanade: 9
# Fairway: 2
# Gap: 14
# Garden: 8
# Gardens: 135
# Gate: 3
# gate: 1
# Gates: 2
# Gelderland: 21
# Grade: 13
# Grange: 1
# Green: 22
# Grove: 87
# Haven: 3
# Heights: 3
# Highgate: 1
# Highway: 89
# Hill: 25
# Lane: 163
# Laneway): 1
# Link: 3
# Loop: 29
# Mews: 112
# Morrison: 1
# North: 9
# Oxford: 1
# Parade: 45
# Parkway: 5
# Pass: 48
# Place: 306
# plaza: 1
# Promenade: 2
# Quarry: 10
# Quays: 1
# Ramble: 13
# Rd: 13
# RD: 14
# Retreat: 74
# Ridgeway: 19
# Rise: 98
# Road: 936
# Road,: 1
# Sava: 6
# Square: 54
# St: 20
# ST: 10
# st: 1
# St): 1
# Street: 1203
# Tce: 1
# Terrace: 96
# Terriace: 1
# Trail: 12
# Turn: 3
# University: 16
# Vale: 32
# View: 35
# Vista: 1
# W/ENT: 3
# WA: 1
# Way: 399
# WAY: 11
# West: 12
# Wharf: 1

# %%
# Check proposed street name updates

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ["Avenue", "Beaufort", "Boulevard", "Boulevarde", "Broadway", "Circle", "Circuit", "Close", "Corner", "Court",
            "Courtyard", "Cove", "Crescent", "Cross", "Crossway", "Dale", "Drive", "East", "Edge", "Elbow", "Entrance",
            "Elbow", "Esplanade", "Fairway", "Gap", "Garden", "Gardens", "Gate", "Gates", "Gelderland", "Grade", "Grange",
            "Green", "Grove", "Haven", "Heights", "Highgate", "Highway", "Hill", "Lane", "Laneway", "Link", "Loop", "Mews",
            "Morrison", "North", "Oxford", "Parade", "Parkway", "Pass", "Place", "Promenade", "Quarry", "Quays", "Ramble",
            "Road", "Retreat", "Ridgeway", "Rise", "Sava", "Square", "Street", "Terrace", "Trail", "Turn", "University", 
            "Vale", "View", "Vista", "Way", "West", "Wharf"]

mapping = { "ave" : "Avenue",
            "avenuet" : "Avenue",
            "cres" : "Crescent",
            "crs" : "Cross",
            "crt" : "Court",
            "ct" : "Court",
            "rd" : "Road",
            "st" : "Street",
            "tce" : "Terrace",
            "terriace" : "Terrace",
            "wa" : "Way"}


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = collections.defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types


def update_name(name, mapping):
    after = []
    
    for part in name.split(" "):
        part = part.strip(",\.").lower()
        
        if part in mapping.keys():
            part = mapping[part]
        after.append(part.capitalize())
    
    return " ".join(after)


ret_st_types = audit(osmfilenm)

for st_type, ways in ret_st_types.iteritems():
    for name in ways:
        proposed_name = update_name(name, mapping)
        print name, "=>", proposed_name
# Out:
# TILLIA CRT => Tillia Court
# POPLAR CRT => Poplar Court
# SORREL CRT => Sorrel Court
# Barrow Cres => Barrow Crescent
# Hero Cres => Hero Crescent
# Fitzgerald St (corner View St) => Fitzgerald Street (corner View St)
# Scarborough Beach Rd => Scarborough Beach Road
# Morilla Rd => Morilla Road
# Rockeby Rd => Rockeby Road
# Runyon Rd => Runyon Road
# Cypress Rd => Cypress Road
# Reynolds Rd => Reynolds Road
# TARATA WY E/ENT (LANEWAY) => Tarata Wy E/ent (laneway)
# Starling st => Starling Street
# Boas Avenuet => Boas Avenue
# Beaufort St WA => Beaufort Street Way
# Beasley Road, => Beasley Road
# CYPRESS RD => Cypress Road
# REYNOLDS RD => Reynolds Road
# TARATA WY E/ENT => Tarata Wy E/ent
# TARATA WAY E/ENT => Tarata Way E/ent
# Edjudina gate => Edjudina Gate
# Bradshaw Crs => Bradshaw Cross
# TARATA WAY SW ENTRANCE => Tarata Way Sw Entrance
# Tillia Crt => Tillia Court
# Sorrel Crt => Sorrel Court
# Hay St => Hay Street
# William St => William Street
# Hill St => Hill Street
# Foundry St => Foundry Street
# Newcastle St => Newcastle Street
# Fitzgerald St => Fitzgerald Street
# Hicks St => Hicks Street
# CARISSA WAY => Carissa Way
# LINDEN WAY => Linden Way
# E Linden Way (In Laneway) => E Linden Way (in Laneway)
# St Georges Terriace => Street Georges Terrace
# Waterford plaza => Waterford Plaza
# TARATA WY W/ENT => Tarata Wy W/ent
# Elderberry drive => Elderberry Drive
# HICKS ST => Hicks Street
# Tarata Wy E/Ent => Tarata Wy E/ent
# Hobsons Ave => Hobsons Avenue
# Wordsworth Ave => Wordsworth Avenue
# Albion Ave => Albion Avenue
# Parmelia Ave => Parmelia Avenue
# Frobisher Ave => Frobisher Avenue
# St Georges Tce => Street Georges Terrace
# O'Kane Ct => O'kane Court
# Magazine Ct => Magazine Court

# %%
# Clean data and write to a json file

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]
LOCATION = ['lat','lon']

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def update_name(name, mapping):
    match = street_type_re.search(name)
    match = match.group(0)
    
    if match in mapping.keys():
        name = name.replace(match,mapping[match])
        
    return name


def clean_street_name(street_name):
    street_name = street_name.title()
    street_name = street_name.split(",")[0]
    street_name = street_name.split("(")[0]
    street_name = street_name.strip()
    street_name = update_name(street_name, mapping)

    return street_name


def is_postal_code(elem):
    return (elem.attrib['k'] == "addr:postcode")


def clean_postal_code(postcode):
    return postcode.replace(" ","")


def shape_element(element):
    node = {}
    node['created'] = dict()

    if element.tag == "node" or element.tag == "way" :
        node['type'] = element.tag
        attributes = element.attrib

        for key, value in attributes.items():
            if key in CREATED:
                node['created'][key] = value
            elif key in LOCATION:
                node.setdefault('pos',[]).insert(0,float(value))
            else:
                node[key] = value

        for child in element:
            if child.tag == 'nd':
                node.setdefault('node_refs',[]).append(child.attrib['ref'])
            elif child.tag == 'tag':
                k = child.attrib['k']
                v = child.attrib['v']

                if is_street_name(child):
                    v = clean_street_name(v)

                if is_postal_code(child):
                    v = clean_postal_code(v)
                    if len(v) > 6:
                        continue

                if problemchars.search(k) or k.count(":") > 1:
                    pass
                elif k.startswith('addr:'):
                    node.setdefault('address',{})[ k.split(":")[1] ] = v
                else:
                    node[k] = v
                    
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data


data = process_map(osmfilenm, True)
pprint.pprint(data[0])
# Out:
# {'created': {'changeset': '12341071',
#              'timestamp': '2012-07-19T17:00:36Z',
#              'uid': '722137',
#              'user': 'OSMF Redaction Account',
#              'version': '9'},
#  'id': '2306306',
#  'pos': [-32.0388963, 115.7735345],
#  'type': 'node'}

# %%
def process_map(file_in, limiter, pretty = False):     
    #initialize pymongo connection and db.collection schema
    from pymongo import MongoClient
    client = MongoClient("mongodb://localhost:27017")
    db = 'data/perth_australia.osm'
    elements = db.elements
    elements.drop()
    
    #process the osm doc
    file_out = "{0}.json".format(file_in.split('.')[0])
    i=0
    with codecs.open(file_out, "w") as fo:
        for event, element in ET.iterparse(file_in):
            if i > limiter and limiter != -1:
                break
            i+=1
            el = shape_element(element)
            if el:
                #write to mongo
                elements.insert(el)
                #write to file
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
                    element.clear()
    return file_out

data = process_map(osmfilenm, True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-208a102277eb> in <module>()
#      27     return file_out
#      28
# ---> 29 data = process_map(osmfilenm, True)
#
# <ipython-input-81-208a102277eb> in process_map(file_in, limiter, pretty)
#       4     client = MongoClient("mongodb://localhost:27017")
#       5     db = 'data/perth_australia.osm'
# ----> 6     elements = db.elements
#       7     elements.drop()
#       8
#
# AttributeError: 'str' object has no attribute 'elements'

# %%
## Load json data in pymongo

from pymongo import MongoClient

def get_db(db_name):
    client = MongoClient("mongodb://localhost:27017")
    db = client[db_name]
    return db

def get_collection(db, collection):
    collections_db = db[collection]
    return collections_db

def insert_data(json_data, db_collection):
    with open(json_data, 'r') as f:
        for each_line in f.readlines():
            db_collection.insert(json.loads(each_line))
    print("Complete.")

def map_aggregate(db, collection, pipeline):
    db_collection = db[collection]
    result = db_collection.aggregate(pipeline)
    return result

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017")
db = 'data/perth_australia.osm'
elements = db.elements

count = elements.find().count()
print 'elements.find().count()'
print 'number of elements: {}\n'.format(count)
# Out:
# elements.find().count()
# number of elements: 0

# %%
nodes = elements.find({"type":"node"}).count()
print 'elemnts.find({"type":"node"}).count()'
print 'number of node elements: {}\n'.format(nodes)

# %%
# Top user contributions overall grouped by city

def make_city_pipeline(city):
    pipeline = [{"$match":{"created.user":{"$exists":1},
                                          "city_name":city}},
                 {"$group": {"_id": {"City":"$city_name",
                                     "User":"$created.user"},
                            "count": {"$sum": 1}}},                            
                 {"$project": {'_id':0,
                               "City":"$_id.City",
                               "User":"$_id.User",
                               "Count":"$count"}},
                 {"$sort": {"Count": -1}},
                 {"$limit" : 5 }]
    return pipeline

pipeline = make_city_pipeline('perth')
result1 = map_aggregate(db, 'cities', pipeline)
pprint.pprint(result1)
# Out:
# <pymongo.command_cursor.CommandCursor object at 0x00000000C4D4D630>

# %%
db.perth.aggregate( [ { $group : { "_id" : "$type", "count" : { $sum : 1 } } } ] )
# Out:
#   File "<ipython-input-45-6205809cd3e2>", line 1
#     db.perth.aggregate( [ { $group : { "_id" : "$type", "count" : { $sum : 1 } } } ] )
#                             ^
# SyntaxError: invalid syntax

# %%
OSMFILE = "data/perth_australia.osm"

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]

expected = ["Avenue", "Beaufort", "Boulevard", "Boulevarde", "Broadway", "Circle", "Circuit", "Close", "Corner", "Court",
            "Courtyard", "Cove", "Crescent", "Cross", "Crossway", "Dale", "Drive", "East", "Edge", "Elbow", "Entrance",
            "Elbow", "Esplanade", "Fairway", "Gap", "Garden", "Gardens", "Gate", "Gates", "Gelderland", "Grade", "Grange",
            "Green", "Grove", "Haven", "Heights", "Highgate", "Highway", "Hill", "Lane", "Laneway", "Link", "Loop", "Mews",
            "Morrison", "North", "Oxford", "Parade", "Parkway", "Pass", "Place", "Promenade", "Quarry", "Quays", "Ramble",
            "Road", "Retreat", "Ridgeway", "Rise", "Sava", "Square", "Street", "Terrace", "Trail", "Turn", "University", 
            "Vale", "View", "Vista", "Way", "West", "Wharf"]

street_mapping = {"ave" : "Avenue",
            "avenuet" : "Avenue",
            "cres" : "Crescent",
            "crs" : "Cross",
            "crt" : "Court",
            "ct" : "Court",
            "rd" : "Road",
            "st" : "Street",
            "tce" : "Terrace",
            "terriace" : "Terrace",
            "wa" : "Way"}

postal_code_range = [6000,7000]
postal_code_default = 6000

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def audit_postal_code(invalid_postal_codes, postal_code):
    try:
        if not (postal_code_range[0] <= int(postal_code) <= postal_code_range[1]):
            raise ValueError
    except ValueError:
        invalid_postal_codes[postal_code] += 1

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def is_postal_code(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    invalid_postal_codes = defaultdict(int)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
                elif is_postal_code(tag):
                    audit_postal_code(invalid_postal_codes, tag.attrib['v'])

    return [invalid_postal_codes, street_types]

#standardizes street types with a replacement map
def update_name(name, mapping):
    name = name.split(' ')
    type = name[-1]
    if type in mapping:
        name[-1] = mapping[type]
    
    name = ' '.join(name)
    name = name.title()

    return name

#checks if postal code within valid range, if not replaces with 11000 default
def update_postal_code(postal_code):
    try:
        if not (postal_code_range[0] <= int(postal_code) <= postal_code_range[1]):
            raise ValueError
        else:
            return int(postal_code)
    except ValueError:
        return postal_code_default

def shape_element(e):
    node = {}
    node['created'] = {}
    node['pos'] = [0,0]
    if e.tag == "way":
        node['node_refs'] = []
    if e.tag == "node" or e.tag == "way" :
        node['type'] = e.tag
        #attributes
        for k, v in e.attrib.iteritems():
            #latitude
            if k == 'lat':
                try:
                    lat = float(v)
                    node['pos'][0] = lat
                except ValueError:
                    pass
            #longitude
            elif k == 'lon':
                try:
                    lon = float(v)
                    node['pos'][1] = lon
                except ValueError:
                    pass
            #creation metadata
            elif k in CREATED:
                node['created'][k] = v
            else:
                node[k] = v
        #children
        for tag in e.iter('tag'):
            k = tag.attrib['k']
            v = tag.attrib['v']
            if problemchars.match(k):
                continue
            elif lower_colon.match(k):
                k_split = k.split(':')
                #address fields
                if k_split[0] == 'addr':
                    k_item = k_split[1]
                    if 'address' not in node:
                        node['address'] = {}
                    #streets
                    if k_item == 'street':
                        v = update_name(v, street_mapping)                    
                    #postal codes
                    if k_item == 'postcode':
                        v = update_postal_code(v)
                    node['address'][k_item] = v
                    continue
            node[k] = v
        #way children
        if e.tag == "way":
            for n in e.iter('nd'):
                ref = n.attrib['ref']
                node['node_refs'].append(ref);
        return node
    else:
        return None

def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data

def audit_report():
    audit_data = audit(OSMFILE)
    pprint.pprint(audit_data[0])
    pprint.pprint(audit_data[1])
    pprint.pprint(dict(audit_data[2]))

'''
PRINT OUT AUDIT REPORT
'''
#audit_report()

'''
PROCESS DATA AND OUTPUT JSON
'''
process_map(OSMFILE, False)
# Out:
# [{'created': {'changeset': '12341071',
#    'timestamp': '2012-07-19T17:00:36Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '9'},
#   'id': '2306306',
#   'pos': [-32.0388963, 115.7735345],
#   'type': 'node'},
#  {'created': {'changeset': '12548730',
#    'timestamp': '2012-07-30T14:14:36Z',
#    'uid': '142807',
#    'user': 'SDavies',
#    'version': '3'},
#   'id': '21390176',
#   'pos': [-31.9624823, 115.9130943],
#   'type': 'node'},
#  {'created': {'changeset': '12543711',
#    'timestamp': '2012-07-30T06:41:54Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '3'},
#   'id': '21390184',
#   'pos': [-31.9566591, 115.9019806],
#   'type': 'node'},
#  {'created': {'changeset': '12543711',
#    'timestamp': '2012-07-30T06:41:54Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '4'},
#   'id': '21390189',
#   'pos': [-31.9550943, 115.8999843],
#   'type': 'node'},
#  {'created': {'changeset': '12543711',
#    'timestamp': '2012-07-30T06:43:33Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '3'},
#   'id': '21390190',
#   'pos': [-31.9545536, 115.8990236],
#   'type': 'node'},
#  {'created': {'changeset': '12543711',
#    'timestamp': '2012-07-30T06:43:33Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '3'},
#   'id': '21390191',
#   'pos': [-31.9539488, 115.897975],
#   'type': 'node'},
#  {'created': {'changeset': '12543711',
#    'timestamp': '2012-07-30T06:43:33Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '3'},
#   'id': '21390192',
#   'pos': [-31.9535014, 115.8973501],
#   'type': 'node'},
#  {'created': {'changeset': '12543711',
#    'timestamp': '2012-07-30T06:43:33Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '6'},
#   'id': '21390193',
#   'pos': [-31.9530776, 115.8968081],
#   'type': 'node'},
#  {'created': {'changeset': '12543711',
#    'timestamp': '2012-07-30T06:43:33Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '3'},
#   'id': '21390196',
#   'pos': [-31.9524006, 115.8961134],
#   'type': 'node'},
#  {'created': {'changeset': '12543711',
#    'timestamp': '2012-07-30T06:43:33Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '3'},
#   'id': '21390197',
#   'pos': [-31.9518352, 115.8956188],
#   'type': 'node'},
#  {'created': {'changeset': '12543711',
#    'timestamp': '2012-07-30T06:43:34Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '3'},
#   'id': '21390198',
#   'pos': [-31.9505772, 115.8945776],
#   'type': 'node'},
#  {'created': {'changeset': '12543711',
#    'timestamp': '2012-07-30T06:43:34Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '3'},
#   'id': '21390201',
#   'pos': [-31.9492877, 115.8932722],
#   'type': 'node'},
#  {'created': {'changeset': '12543711',
#    'timestamp': '2012-07-30T06:43:34Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '3'},
#   'id': '21390202',
#   'pos': [-31.9486699, 115.8924387],
#   'type': 'node'},
#  {'created': {'changeset': '12543711',
#    'timestamp': '2012-07-30T06:43:34Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '4'},
#   'id': '21390203',
#   'pos': [-31.9481107, 115.8914384],
#   'type': 'node'},
#  {'created': {'changeset': '3469335',
#    'timestamp': '2009-12-28T08:23:29Z',
#    'uid': '16558',
#    'user': 'tiger_old',
#    'version': '4'},
#   'id': '21390204',
#   'pos': [-31.9476889, 115.8903119],
#   'type': 'node'},
#  {'created': {'changeset': '39143',
#    'timestamp': '2008-04-03T14:52:48Z',
#    'uid': '32729',
#    'user': 'NickNewton',
#    'version': '3'},
#   'created_by': 'JOSM',
#   'id': '21390205',
#   'pos': [-31.9473438, 115.8889186],
#   'type': 'node'},
#  {'created': {'changeset': '39143',
#    'timestamp': '2008-04-03T14:52:48Z',
#    'uid': '32729',
#    'user': 'NickNewton',
#    'version': '3'},
#   'created_by': 'JOSM',
#   'id': '21390206',
#   'pos': [-31.9472564, 115.888232],
#   'type': 'node'},
#  {'created': {'changeset': '10558',
#    'timestamp': '2008-04-01T18:12:40Z',
#    'uid': '32729',
#    'user': 'NickNewton',
#    'version': '2'},
#   'created_by': 'JOSM',
#   'id': '21390207',
#   'pos': [-31.9472072, 115.8875595],
#   'type': 'node'},
#  {'created': {'changeset': '3105765',
#    'timestamp': '2009-11-13T13:27:45Z',
#    'uid': '13203',
#    'user': 'bahnpirat',
#    'version': '5'},
#   'id': '21390208',
#   'pos': [-31.9472336, 115.8862898],
#   'type': 'node'},
#  {'created': {'changeset': '71194',
#    'timestamp': '2008-10-05T06:58:34Z',
#    'uid': '16385',
#    'user': 'morb_au',
#    'version': '3'},
#   'created_by': 'JOSM',
#   'id': '21390209',
#   'pos': [-31.9473363, 115.8851169],
#   'type': 'node'},
#  {'created': {'changeset': '21626152',
#    'timestamp': '2014-04-11T12:34:49Z',
#    'uid': '943785',
#    'user': 'sb9576',
#    'version': '7'},
#   'id': '21390212',
#   'pos': [-31.9475339, 115.8808203],
#   'type': 'node'},
#  {'created': {'changeset': '3897885',
#    'timestamp': '2010-02-17T02:31:28Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '4'},
#   'id': '21390213',
#   'pos': [-31.9476276, 115.8801645],
#   'type': 'node'},
#  {'created': {'changeset': '3897885',
#    'timestamp': '2010-02-17T02:31:28Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '4'},
#   'id': '21390214',
#   'pos': [-31.9476204, 115.8789028],
#   'type': 'node'},
#  {'created': {'changeset': '3897885',
#    'timestamp': '2010-02-17T02:31:28Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '21390215',
#   'pos': [-31.9476019, 115.8771586],
#   'type': 'node'},
#  {'created': {'changeset': '3897885',
#    'timestamp': '2010-02-17T02:31:27Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '21390216',
#   'pos': [-31.9476164, 115.8760512],
#   'type': 'node'},
#  {'created': {'changeset': '3897885',
#    'timestamp': '2010-02-17T02:31:27Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '3'},
#   'id': '21390217',
#   'pos': [-31.9478759, 115.8744939],
#   'type': 'node'},
#  {'created': {'changeset': '3897885',
#    'timestamp': '2010-02-17T02:31:27Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '4'},
#   'id': '21390218',
#   'pos': [-31.9485963, 115.8728014],
#   'type': 'node'},
#  {'created': {'changeset': '3897885',
#    'timestamp': '2010-02-17T02:31:27Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '4'},
#   'id': '21390219',
#   'pos': [-31.9493173, 115.8715042],
#   'type': 'node'},
#  {'created': {'changeset': '3282838',
#    'timestamp': '2009-12-03T18:32:25Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '6'},
#   'id': '21390248',
#   'pos': [-31.9447547, 115.8414139],
#   'type': 'node'},
#  {'created': {'changeset': '3282838',
#    'timestamp': '2009-12-03T18:32:10Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '9'},
#   'id': '21390249',
#   'pos': [-31.9456999, 115.8409933],
#   'type': 'node'},
#  {'created': {'changeset': '3282838',
#    'timestamp': '2009-12-03T18:32:01Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '5'},
#   'id': '21390251',
#   'pos': [-31.9475186, 115.8401701],
#   'type': 'node'},
#  {'created': {'changeset': '12325904',
#    'timestamp': '2012-07-19T12:40:07Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '21390252',
#   'pos': [-31.9480064, 115.8399536],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:50:07Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587702',
#   'pos': [-32.0529736, 115.731796],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:50:11Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587703',
#   'pos': [-32.0531645, 115.7322574],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:50:12Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587704',
#   'pos': [-32.0532464, 115.732531],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:50:24Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587705',
#   'pos': [-32.0532464, 115.7328045],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:50:16Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587706',
#   'pos': [-32.0531554, 115.7337701],
#   'type': 'node'},
#  {'created': {'changeset': '755302',
#    'timestamp': '2009-03-08T09:35:36Z',
#    'uid': '7568',
#    'user': 'user_7568',
#    'version': '2'},
#   'id': '25587710',
#   'pos': [-32.0480721, 115.7350557],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:55:47Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587739',
#   'pos': [-32.0469245, 115.7359343],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:55:48Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587740',
#   'pos': [-32.0463516, 115.7364868],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:55:50Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587741',
#   'pos': [-32.0458468, 115.7354193],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:55:51Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587742',
#   'pos': [-32.0454422, 115.7345771],
#   'type': 'node'},
#  {'created': {'changeset': '10293546',
#    'timestamp': '2012-01-04T18:00:59Z',
#    'uid': '142807',
#    'user': 'SDavies',
#    'version': '2'},
#   'id': '25587743',
#   'pos': [-32.0453207, 115.7340797],
#   'type': 'node'},
#  {'created': {'changeset': '10293546',
#    'timestamp': '2012-01-04T18:01:00Z',
#    'uid': '142807',
#    'user': 'SDavies',
#    'version': '2'},
#   'id': '25587744',
#   'pos': [-32.045311, 115.7337251],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:55:55Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587745',
#   'pos': [-32.0454876, 115.7333379],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:55:57Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587746',
#   'pos': [-32.046156, 115.7342659],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:55:58Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587747',
#   'pos': [-32.0460787, 115.7339655],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:55:59Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587748',
#   'pos': [-32.0461151, 115.7337188],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:56:01Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587749',
#   'pos': [-32.0462697, 115.7334881],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:56:51Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587755',
#   'pos': [-32.0460958, 115.7324278],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:56:54Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587757',
#   'pos': [-32.0468052, 115.7314193],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:56:55Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587758',
#   'pos': [-32.047269, 115.7310921],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:57:00Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587759',
#   'pos': [-32.0468597, 115.7326049],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:57:04Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587760',
#   'pos': [-32.0475009, 115.7338548],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:57:33Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587761',
#   'pos': [-32.0484057, 115.7303303],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:57:35Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587762',
#   'pos': [-32.0497152, 115.7294399],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:58:29Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587763',
#   'pos': [-32.051007, 115.7285846],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:58:30Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587764',
#   'pos': [-32.0522119, 115.7277853],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:58:53Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587765',
#   'pos': [-32.0537942, 115.7252641],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:58:55Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587766',
#   'pos': [-32.0537214, 115.7262243],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:58:56Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587767',
#   'pos': [-32.0536168, 115.7265891],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:58:57Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587768',
#   'pos': [-32.0533577, 115.7270021],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:58:59Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587769',
#   'pos': [-32.053485, 115.7268251],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:59:00Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587770',
#   'pos': [-32.0531031, 115.7272114],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:59:03Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587771',
#   'pos': [-32.0528439, 115.7273884],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T15:59:14Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587772',
#   'pos': [-32.0525393, 115.7275815],
#   'type': 'node'},
#  {'created': {'changeset': '11832',
#    'timestamp': '2007-10-01T14:12:06Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '1'},
#   'id': '25587773',
#   'pos': [-32.0538644, 115.7247485],
#   'type': 'node'},
#  {'created': {'changeset': '3838494',
#    'timestamp': '2010-02-10T09:02:29Z',
#    'uid': '36235',
#    'user': 'Sam Wilson',
#    'version': '2'},
#   'id': '25587774',
#   'pos': [-32.0558824, 115.7328825],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:00:11Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587775',
#   'pos': [-32.0558083, 115.7332785],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:00:11Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587776',
#   'pos': [-32.0558128, 115.7339008],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:00:12Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587777',
#   'pos': [-32.0558401, 115.7345231],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:02:02Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587778',
#   'pos': [-32.0558674, 115.7350595],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:00:14Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587779',
#   'pos': [-32.055922, 115.735671],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:00:15Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587780',
#   'pos': [-32.0560038, 115.7362128],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:00:16Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587781',
#   'pos': [-32.0560993, 115.7368351],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:02:03Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587782',
#   'pos': [-32.0562129, 115.737393],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:02:03Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587783',
#   'pos': [-32.0562993, 115.7377846],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:02:03Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587784',
#   'pos': [-32.056413, 115.7382728],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:02:03Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587785',
#   'pos': [-32.0564948, 115.7386268],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:02:04Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587786',
#   'pos': [-32.0566039, 115.7388951],
#   'type': 'node'},
#  {'created': {'changeset': '528454',
#    'timestamp': '2007-09-28T15:12:39Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '1'},
#   'id': '25587787',
#   'pos': [-32.056678, 115.7391702],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:02:04Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587788',
#   'pos': [-32.0566903, 115.7395334],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:02:04Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587789',
#   'pos': [-32.0566403, 115.7399143],
#   'type': 'node'},
#  {'created': {'changeset': '206406',
#    'timestamp': '2007-02-01T16:02:36Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25587790',
#   'pos': [-32.0564493, 115.7400377],
#   'type': 'node'},
#  {'created': {'changeset': '3847731',
#    'timestamp': '2010-02-11T12:16:31Z',
#    'uid': '36235',
#    'user': 'Sam Wilson',
#    'version': '2'},
#   'id': '25587791',
#   'pos': [-32.0554975, 115.7404291],
#   'type': 'node'},
#  {'created': {'changeset': '3847731',
#    'timestamp': '2010-02-11T12:15:37Z',
#    'uid': '36235',
#    'user': 'Sam Wilson',
#    'version': '4'},
#   'id': '25587792',
#   'pos': [-32.0549213, 115.7413049],
#   'type': 'node'},
#  {'created': {'changeset': '12801959',
#    'timestamp': '2012-08-20T22:00:09Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'highway': 'turning_circle',
#   'id': '25592040',
#   'pos': [-32.3220261, 115.8779997],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:27:49Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592064',
#   'pos': [-32.3220385, 115.857358],
#   'type': 'node'},
#  {'created': {'changeset': '12801959',
#    'timestamp': '2012-08-20T22:00:09Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592065',
#   'pos': [-32.3248144, 115.8576316],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:28:15Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592080',
#   'pos': [-32.3219569, 115.857712],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:28:16Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592081',
#   'pos': [-32.3219297, 115.8582163],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:28:17Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592082',
#   'pos': [-32.3219025, 115.858624],
#   'type': 'node'},
#  {'created': {'changeset': '12801959',
#    'timestamp': '2012-08-20T22:00:09Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592098',
#   'pos': [-32.3257664, 115.8578547],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:30:23Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592100',
#   'pos': [-32.3163536, 115.8561563],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:30:24Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592101',
#   'pos': [-32.3174145, 115.8563495],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:30:25Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592102',
#   'pos': [-32.3178406, 115.8564782],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:30:26Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592103',
#   'pos': [-32.3181308, 115.856607],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:30:29Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592105',
#   'pos': [-32.3186294, 115.8568215],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:30:30Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592106',
#   'pos': [-32.3189014, 115.8569717],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:30:37Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592108',
#   'pos': [-32.3193457, 115.8571005],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:30:38Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592109',
#   'pos': [-32.3200529, 115.8571863],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:30:40Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592110',
#   'pos': [-32.3196812, 115.8571756],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:30:41Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592111',
#   'pos': [-32.3214582, 115.8572829],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:32:20Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592154',
#   'pos': [-32.3118851, 115.8564062],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:32:20Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592155',
#   'pos': [-32.3125198, 115.8562882],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:32:22Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592156',
#   'pos': [-32.3134175, 115.8561594],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:32:23Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592157',
#   'pos': [-32.3143605, 115.8560414],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:32:24Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592158',
#   'pos': [-32.3147594, 115.8559878],
#   'type': 'node'},
#  {'created': {'changeset': '30053934',
#    'timestamp': '2015-04-08T03:59:28Z',
#    'uid': '2800919',
#    'user': 'Cadpete',
#    'version': '2'},
#   'id': '25592159',
#   'pos': [-32.3151754, 115.8559726],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:32:29Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592160',
#   'pos': [-32.3153851, 115.8559878],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:33:37Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592161',
#   'pos': [-32.3068706, 115.855741],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:33:38Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592162',
#   'pos': [-32.3075235, 115.8557303],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:33:40Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592163',
#   'pos': [-32.3086117, 115.8558912],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:33:42Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592164',
#   'pos': [-32.3080495, 115.8558054],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:33:44Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592165',
#   'pos': [-32.3096091, 115.8560522],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:33:46Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592166',
#   'pos': [-32.3100172, 115.8560951],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:33:47Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592167',
#   'pos': [-32.3106428, 115.8562453],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:33:49Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592169',
#   'pos': [-32.3111234, 115.8563526],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:33:50Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592171',
#   'pos': [-32.3115315, 115.8564062],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:34:02Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592177',
#   'pos': [-32.3086389, 115.8614166],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:34:48Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592188',
#   'pos': [-32.3057099, 115.8485527],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:34:50Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592190',
#   'pos': [-32.3057009, 115.8503444],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:34:51Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592191',
#   'pos': [-32.3057099, 115.8523293],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:34:52Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592193',
#   'pos': [-32.3057281, 115.8539922],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:34:54Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592195',
#   'pos': [-32.3057281, 115.85499],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:34:57Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592197',
#   'pos': [-32.3057915, 115.8552153],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:34:58Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592198',
#   'pos': [-32.3058732, 115.8553762],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:34:58Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592199',
#   'pos': [-32.305991, 115.8555157],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:34:58Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592200',
#   'pos': [-32.3061633, 115.8556337],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:34:59Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592201',
#   'pos': [-32.3063628, 115.8556874],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:35:00Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592202',
#   'pos': [-32.3065714, 115.8557088],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:35:22Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592212',
#   'pos': [-32.3047396, 115.8487887],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:35:24Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592213',
#   'pos': [-32.3040505, 115.8489282],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:35:25Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592214',
#   'pos': [-32.3037784, 115.8489282],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:35:27Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592215',
#   'pos': [-32.3023275, 115.8489497],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:35:30Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592216',
#   'pos': [-32.307587, 115.8480484],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:35:38Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592217',
#   'pos': [-32.3030892, 115.8489604],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:37:02Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592244',
#   'pos': [-32.30532, 115.8397872],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:37:03Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592245',
#   'pos': [-32.3055104, 115.8405061],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:37:04Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592246',
#   'pos': [-32.3056102, 115.8409889],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:37:05Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592247',
#   'pos': [-32.3056374, 115.8413],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:37:07Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592248',
#   'pos': [-32.3056737, 115.8418686],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:37:10Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592249',
#   'pos': [-32.3056555, 115.8439393],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:37:25Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592250',
#   'pos': [-32.3056646, 115.8462031],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:38:02Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592253',
#   'pos': [-32.3049754, 115.8380384],
#   'type': 'node'},
#  {'created': {'changeset': '12686553',
#    'timestamp': '2012-08-11T00:59:44Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592256',
#   'pos': [-32.3049696, 115.8337354],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:38:09Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592257',
#   'pos': [-32.3049301, 115.8351309],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:38:10Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592258',
#   'pos': [-32.3049301, 115.8365364],
#   'type': 'node'},
#  {'created': {'changeset': '12801959',
#    'timestamp': '2012-08-20T22:00:09Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592263',
#   'pos': [-32.3086451, 115.8370508],
#   'type': 'node'},
#  {'created': {'changeset': '4676861',
#    'timestamp': '2010-05-12T12:38:07Z',
#    'uid': '192584',
#    'user': 'ORYX',
#    'version': '2'},
#   'highway': 'turning_circle',
#   'id': '25592328',
#   'pos': [-32.3049725, 115.8318996],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:54Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '4'},
#   'id': '25592425',
#   'pos': [-32.3049583, 115.8231931],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:54Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '4'},
#   'id': '25592429',
#   'pos': [-32.3073916, 115.8225345],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:54Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592430',
#   'pos': [-32.3078218, 115.8207643],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:54Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592437',
#   'pos': [-32.3079579, 115.8198921],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:54Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '4'},
#   'id': '25592438',
#   'pos': [-32.3079267, 115.8202121],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:54Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '4'},
#   'id': '25592439',
#   'pos': [-32.3081666, 115.8201129],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:54Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '4'},
#   'id': '25592440',
#   'pos': [-32.3084158, 115.8198627],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:46:33Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592462',
#   'pos': [-32.3091557, 115.8078582],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:46:34Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592463',
#   'pos': [-32.308929, 115.8080943],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:46:35Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592464',
#   'pos': [-32.308793, 115.8083839],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:46:36Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592466',
#   'pos': [-32.3085935, 115.8090169],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:55Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592468',
#   'pos': [-32.3081983, 115.8103374],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:55Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592470',
#   'pos': [-32.3080473, 115.8109296],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:55Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '4'},
#   'id': '25592471',
#   'pos': [-32.3079733, 115.811634],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:55Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592482',
#   'pos': [-32.3101679, 115.8069277],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:55Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592489',
#   'pos': [-32.3106447, 115.798952],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:47:44Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592490',
#   'pos': [-32.31067, 115.7996078],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:55Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592492',
#   'pos': [-32.3106714, 115.8002346],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:55Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592494',
#   'pos': [-32.3106862, 115.8008759],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:55Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592496',
#   'pos': [-32.3107247, 115.8016328],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:47:56Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592498',
#   'pos': [-32.3110418, 115.802644],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:55Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592499',
#   'pos': [-32.311166, 115.8031151],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:55Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592500',
#   'pos': [-32.3112223, 115.8035216],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:47:57Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592501',
#   'pos': [-32.3112413, 115.8040173],
#   'type': 'node'},
#  {'created': {'changeset': '206606',
#    'timestamp': '2007-02-01T21:47:57Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25592503',
#   'pos': [-32.3112594, 115.8044894],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:55Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592507',
#   'pos': [-32.3110949, 115.8058554],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:55Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592509',
#   'pos': [-32.3110061, 115.8061288],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:55Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592511',
#   'pos': [-32.3109172, 115.80629],
#   'type': 'node'},
#  {'created': {'changeset': '12754127',
#    'timestamp': '2012-08-16T18:54:55Z',
#    'uid': '418724',
#    'user': 'wintersportler',
#    'version': '2'},
#   'id': '25592512',
#   'pos': [-32.3106684, 115.8065283],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:45:09Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596510',
#   'pos': [-32.0922922, 115.7607917],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:45:13Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596512',
#   'pos': [-32.0938101, 115.7612208],
#   'type': 'node'},
#  {'created': {'changeset': '538136',
#    'timestamp': '2007-09-30T11:35:08Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '1'},
#   'id': '25596517',
#   'pos': [-32.0909399, 115.7589273],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:46:44Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596518',
#   'pos': [-32.0908106, 115.7592735],
#   'type': 'node'},
#  {'created': {'changeset': '538136',
#    'timestamp': '2007-09-30T11:35:09Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '1'},
#   'id': '25596519',
#   'pos': [-32.0906833, 115.7595632],
#   'railway': 'level_crossing',
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:46:03Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596520',
#   'pos': [-32.0905833, 115.7598529],
#   'type': 'node'},
#  {'created': {'changeset': '4961132',
#    'timestamp': '2010-06-11T09:57:35Z',
#    'uid': '36235',
#    'user': 'Sam Wilson',
#    'version': '2'},
#   'id': '25596521',
#   'pos': [-32.0905301, 115.7601617],
#   'type': 'node'},
#  {'created': {'changeset': '11607367',
#    'timestamp': '2012-05-15T18:06:28Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '2'},
#   'id': '25596522',
#   'pos': [-32.0905237, 115.7605552],
#   'type': 'node'},
#  {'created': {'changeset': '11607367',
#    'timestamp': '2012-05-15T18:06:28Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '4'},
#   'id': '25596523',
#   'pos': [-32.0905081, 115.76117],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:47:27Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596526',
#   'pos': [-32.0911014, 115.7585493],
#   'type': 'node'},
#  {'created': {'changeset': '10995547',
#    'timestamp': '2012-03-16T06:57:48Z',
#    'uid': '36235',
#    'user': 'Sam Wilson',
#    'version': '2'},
#   'id': '25596527',
#   'pos': [-32.0912552, 115.7580409],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:47:31Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596529',
#   'pos': [-32.0913105, 115.7576267],
#   'type': 'node'},
#  {'created': {'changeset': '538136',
#    'timestamp': '2007-09-30T11:35:18Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '1'},
#   'id': '25596530',
#   'pos': [-32.0905769, 115.7587396],
#   'type': 'node'},
#  {'created': {'changeset': '538136',
#    'timestamp': '2007-09-30T11:35:17Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '1'},
#   'id': '25596531',
#   'pos': [-32.0902268, 115.7585427],
#   'type': 'node'},
#  {'created': {'changeset': '538136',
#    'timestamp': '2007-09-30T11:35:14Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '1'},
#   'id': '25596532',
#   'pos': [-32.0899932, 115.7583641],
#   'type': 'node'},
#  {'created': {'changeset': '538136',
#    'timestamp': '2007-09-30T11:35:13Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '1'},
#   'id': '25596533',
#   'pos': [-32.0897643, 115.7581438],
#   'type': 'node'},
#  {'created': {'changeset': '538136',
#    'timestamp': '2007-09-30T11:35:16Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '1'},
#   'id': '25596534',
#   'pos': [-32.0895035, 115.7578612],
#   'type': 'node'},
#  {'created': {'changeset': '538136',
#    'timestamp': '2007-09-30T11:35:15Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '1'},
#   'id': '25596535',
#   'pos': [-32.0890172, 115.7575038],
#   'type': 'node'},
#  {'created': {'changeset': '3040765',
#    'timestamp': '2009-11-05T14:26:35Z',
#    'uid': '13203',
#    'user': 'bahnpirat',
#    'version': '2'},
#   'id': '25596541',
#   'pos': [-32.0885345, 115.7606651],
#   'type': 'node'},
#  {'created': {'changeset': '3040765',
#    'timestamp': '2009-11-05T14:26:34Z',
#    'uid': '13203',
#    'user': 'bahnpirat',
#    'version': '2'},
#   'id': '25596542',
#   'pos': [-32.0886145, 115.7604076],
#   'type': 'node'},
#  {'created': {'changeset': '12341056',
#    'timestamp': '2012-07-19T16:59:57Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '4'},
#   'id': '25596543',
#   'pos': [-32.0885781, 115.759987],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:48:28Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596544',
#   'pos': [-32.0880791, 115.7589195],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:48:31Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596545',
#   'pos': [-32.0874837, 115.7583348],
#   'type': 'node'},
#  {'created': {'changeset': '12398718',
#    'timestamp': '2012-07-21T02:35:13Z',
#    'uid': '36235',
#    'user': 'Sam Wilson',
#    'version': '4'},
#   'id': '25596547',
#   'pos': [-32.0853326, 115.7611685],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:49:32Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596554',
#   'pos': [-32.0846477, 115.7559744],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:49:34Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596556',
#   'pos': [-32.0850522, 115.7560656],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:49:37Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596558',
#   'pos': [-32.0854249, 115.7563124],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:49:40Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596559',
#   'pos': [-32.085643, 115.7564733],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:49:40Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596560',
#   'pos': [-32.085793, 115.7566718],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:49:43Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596561',
#   'pos': [-32.0861475, 115.757058],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:49:46Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596562',
#   'pos': [-32.0867702, 115.7576642],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:49:47Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596563',
#   'pos': [-32.0864611, 115.7581953],
#   'type': 'node'},
#  {'created': {'changeset': '24900810',
#    'timestamp': '2014-08-21T05:18:30Z',
#    'uid': '36235',
#    'user': 'Sam Wilson',
#    'version': '3'},
#   'id': '25596577',
#   'pos': [-32.0821543, 115.7560172],
#   'type': 'node'},
#  {'created': {'changeset': '206865',
#    'timestamp': '2007-02-02T10:52:28Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25596578',
#   'pos': [-32.0838477, 115.755969],
#   'type': 'node'},
#  {'created': {'changeset': '11411911',
#    'timestamp': '2012-04-25T07:32:44Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '3'},
#   'id': '25596600',
#   'pos': [-32.0822225, 115.7544865],
#   'type': 'node'},
#  {'created': {'changeset': '11411911',
#    'timestamp': '2012-04-25T07:32:44Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '3'},
#   'id': '25596601',
#   'pos': [-32.0822157, 115.7535459],
#   'railway': 'level_crossing',
#   'type': 'node'},
#  {'created': {'changeset': '11411911',
#    'timestamp': '2012-04-25T07:32:44Z',
#    'uid': '189263',
#    'user': 'wildmyron',
#    'version': '3'},
#   'id': '25596602',
#   'pos': [-32.082212, 115.7529109],
#   'type': 'node'},
#  {'created': {'changeset': '3880820',
#    'timestamp': '2010-02-15T08:39:36Z',
#    'uid': '36235',
#    'user': 'Sam Wilson',
#    'version': '4'},
#   'id': '25596603',
#   'pos': [-32.0822089, 115.7525106],
#   'type': 'node'},
#  {'created': {'changeset': '538136',
#    'timestamp': '2007-09-30T11:35:01Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '1'},
#   'id': '25596609',
#   'pos': [-32.0806804, 115.7543053],
#   'type': 'node'},
#  {'created': {'changeset': '538136',
#    'timestamp': '2007-09-30T11:35:00Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '1'},
#   'id': '25596610',
#   'pos': [-32.0796961, 115.7541836],
#   'type': 'node'},
#  {'created': {'changeset': '3880820',
#    'timestamp': '2010-02-15T08:20:53Z',
#    'uid': '36235',
#    'user': 'Sam Wilson',
#    'version': '2'},
#   'id': '25596611',
#   'pos': [-32.0797817, 115.7533018],
#   'type': 'node'},
#  {'created': {'changeset': '3880820',
#    'timestamp': '2010-02-15T08:18:40Z',
#    'uid': '36235',
#    'user': 'Sam Wilson',
#    'version': '4'},
#   'disused': 'yes',
#   'id': '25596613',
# ...
#    'uid': '43373',
#    'user': 'swannie',
#    'version': '6'},
#   'id': '25648792',
#   'pos': [-31.9860318, 115.8242341],
#   'type': 'node'},
#  {'created': {'changeset': '355732',
#    'timestamp': '2007-09-06T12:33:35Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '1'},
#   'id': '25648818',
#   'pos': [-31.9863988, 115.8189894],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:17Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25648819',
#   'pos': [-31.9864267, 115.8192771],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:18Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25648820',
#   'pos': [-31.9866182, 115.8201779],
#   'type': 'node'},
#  {'created': {'changeset': '337240',
#    'timestamp': '2007-09-05T15:43:22Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '1'},
#   'id': '25648821',
#   'pos': [-31.9865011, 115.8210184],
#   'type': 'node'},
#  {'created': {'changeset': '16867071',
#    'timestamp': '2013-07-08T00:01:11Z',
#    'uid': '145231',
#    'user': 'woodpeck_repair',
#    'version': '4'},
#   'id': '25648822',
#   'pos': [-31.9862238, 115.8214841],
#   'type': 'node'},
#  {'created': {'changeset': '16867071',
#    'timestamp': '2013-07-08T00:01:11Z',
#    'uid': '145231',
#    'user': 'woodpeck_repair',
#    'version': '4'},
#   'id': '25648823',
#   'pos': [-31.9858183, 115.8218217],
#   'type': 'node'},
#  {'created': {'changeset': '11338322',
#    'timestamp': '2012-04-17T21:32:14Z',
#    'uid': '571888',
#    'user': 'Lumina',
#    'version': '3'},
#   'id': '25648825',
#   'pos': [-31.9846276, 115.8218035],
#   'type': 'node'},
#  {'created': {'changeset': '11338322',
#    'timestamp': '2012-04-17T21:32:14Z',
#    'uid': '571888',
#    'user': 'Lumina',
#    'version': '3'},
#   'id': '25648826',
#   'pos': [-31.9841765, 115.8215555],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:18Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25648827',
#   'pos': [-31.9837006, 115.8213042],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:18Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25648828',
#   'pos': [-31.9832994, 115.8210563],
#   'type': 'node'},
#  {'created': {'changeset': '3196292',
#    'timestamp': '2009-11-23T14:59:01Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25648830',
#   'pos': [-31.9822876, 115.8205399],
#   'type': 'node'},
#  {'created': {'changeset': '179358',
#    'timestamp': '2007-07-31T09:00:30Z',
#    'uid': '9499',
#    'user': 'cameron',
#    'version': '1'},
#   'id': '25648831',
#   'pos': [-31.9782055, 115.8205428],
#   'type': 'node'},
#  {'created': {'changeset': '3281464',
#    'timestamp': '2009-12-03T15:26:47Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25648832',
#   'pos': [-31.9774213, 115.8207866],
#   'type': 'node'},
#  {'created': {'changeset': '3281464',
#    'timestamp': '2009-12-03T15:26:47Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25648833',
#   'pos': [-31.976374, 115.8212095],
#   'type': 'node'},
#  {'created': {'changeset': '3271836',
#    'timestamp': '2009-12-02T13:09:43Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '3'},
#   'id': '25648847',
#   'pos': [-31.9755794, 115.821398],
#   'type': 'node'},
#  {'created': {'changeset': '3220556',
#    'timestamp': '2009-11-26T14:20:44Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656615',
#   'pos': [-31.9758195, 115.8036849],
#   'type': 'node'},
#  {'created': {'changeset': '3220556',
#    'timestamp': '2009-11-26T14:20:44Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656617',
#   'pos': [-31.9758172, 115.8047296],
#   'type': 'node'},
#  {'created': {'changeset': '3220556',
#    'timestamp': '2009-11-26T14:20:44Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656618',
#   'pos': [-31.9758172, 115.8057851],
#   'type': 'node'},
#  {'created': {'changeset': '3220556',
#    'timestamp': '2009-11-26T14:20:44Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656619',
#   'pos': [-31.9761471, 115.8057837],
#   'type': 'node'},
#  {'created': {'changeset': '3220556',
#    'timestamp': '2009-11-26T14:20:49Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656620',
#   'pos': [-31.9761437, 115.8069545],
#   'type': 'node'},
#  {'created': {'changeset': '208768',
#    'timestamp': '2007-02-05T18:20:19Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25656626',
#   'pos': [-31.9775016, 115.8046814],
#   'type': 'node'},
#  {'created': {'changeset': '3213449',
#    'timestamp': '2009-11-25T16:52:14Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656650',
#   'pos': [-31.9777811, 115.7999185],
#   'type': 'node'},
#  {'created': {'changeset': '3213449',
#    'timestamp': '2009-11-25T16:52:20Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656651',
#   'pos': [-31.9777833, 115.8012676],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:14Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '3'},
#   'id': '25656652',
#   'pos': [-31.9777848, 115.8026161],
#   'type': 'node'},
#  {'created': {'changeset': '189123',
#    'timestamp': '2007-08-04T16:40:23Z',
#    'uid': '9499',
#    'user': 'cameron',
#    'version': '1'},
#   'id': '25656683',
#   'pos': [-31.9775505, 115.7960537],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:14Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656684',
#   'pos': [-31.9777646, 115.7972737],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:14Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '3'},
#   'id': '25656685',
#   'pos': [-31.9777765, 115.7985645],
#   'type': 'node'},
#  {'created': {'changeset': '208768',
#    'timestamp': '2007-02-05T18:24:55Z',
#    'uid': '4992',
#    'user': 'johnrobot',
#    'version': '1'},
#   'id': '25656688',
#   'pos': [-31.9777351, 115.7948596],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:10Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656701',
#   'pos': [-31.9822533, 115.7858196],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:10Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656702',
#   'pos': [-31.982108, 115.7868984],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:10Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656703',
#   'pos': [-31.9820745, 115.7871072],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:10Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656704',
#   'pos': [-31.9824022, 115.7847216],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:11Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656705',
#   'pos': [-31.9800271, 115.7869019],
#   'type': 'node'},
#  {'created': {'changeset': '3206686',
#    'timestamp': '2009-11-24T18:51:23Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '2'},
#   'id': '25656707',
#   'pos': [-31.9800507, 115.7847277],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:11Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656708',
#   'pos': [-31.9819013, 115.7880634],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:11Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656709',
#   'pos': [-31.9815119, 115.7902086],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:11Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656710',
#   'pos': [-31.9814701, 115.7904122],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:11Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'highway': 'traffic_signals',
#   'id': '25656723',
#   'pos': [-31.9812876, 115.7913805],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:11Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656724',
#   'pos': [-31.9812279, 115.7917034],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:12Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656725',
#   'pos': [-31.981086, 115.7925274],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:12Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656726',
#   'pos': [-31.981025, 115.7928475],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:12Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656727',
#   'pos': [-31.9808738, 115.7937113],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:12Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656728',
#   'pos': [-31.9808184, 115.7940262],
#   'type': 'node'},
#  {'created': {'changeset': '3220556',
#    'timestamp': '2009-11-26T14:18:43Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656731',
#   'pos': [-31.9824447, 115.7904871],
#   'type': 'node'},
#  {'created': {'changeset': '15487701',
#    'timestamp': '2013-03-25T06:56:55Z',
#    'uid': '215053',
#    'user': 'Richard Stallard',
#    'version': '2'},
#   'id': '25656739',
#   'pos': [-31.9825764, 115.7835149],
#   'type': 'node'},
#  {'created': {'changeset': '3220556',
#    'timestamp': '2009-11-26T14:18:19Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656740',
#   'pos': [-31.9833309, 115.7871102],
#   'type': 'node'},
#  {'created': {'changeset': '3220556',
#    'timestamp': '2009-11-26T14:18:19Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656741',
#   'pos': [-31.9838177, 115.7871048],
#   'type': 'node'},
#  {'created': {'changeset': '3326413',
#    'timestamp': '2009-12-08T17:18:10Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656742',
#   'pos': [-31.9838068, 115.7848898],
#   'type': 'node'},
#  {'created': {'changeset': '4191058',
#    'timestamp': '2010-03-21T13:45:29Z',
#    'uid': '84853',
#    'user': 'mdp553',
#    'version': '4'},
#   'id': '25656743',
#   'noexit': 'yes',
#   'pos': [-31.9837681, 115.783499],
#   'type': 'node'},
#  {'created': {'changeset': '15487701',
#    'timestamp': '2013-03-25T06:56:55Z',
#    'uid': '215053',
#    'user': 'Richard Stallard',
#    'version': '3'},
#   'id': '25656744',
#   'pos': [-31.9824929, 115.7838259],
#   'type': 'node'},
#  {'created': {'changeset': '3350614',
#    'timestamp': '2009-12-11T17:26:46Z',
#    'uid': '16558',
#    'user': 'tiger_old',
#    'version': '2'},
#   'id': '25656745',
#   'pos': [-31.9836249, 115.7798441],
#   'type': 'node'},
#  {'created': {'changeset': '15487701',
#    'timestamp': '2013-03-25T06:56:55Z',
#    'uid': '215053',
#    'user': 'Richard Stallard',
#    'version': '3'},
#   'highway': 'traffic_signals',
#   'id': '25656746',
#   'pos': [-31.9831101, 115.7813749],
#   'type': 'node'},
#  {'created': {'changeset': '15487701',
#    'timestamp': '2013-03-25T06:56:55Z',
#    'uid': '215053',
#    'user': 'Richard Stallard',
#    'version': '6'},
#   'highway': 'traffic_signals',
#   'id': '25656750',
#   'pos': [-31.9827236, 115.782911],
#   'type': 'node'},
#  {'created': {'changeset': '12327812',
#    'timestamp': '2012-07-19T13:02:51Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '6'},
#   'highway': 'traffic_signals',
#   'id': '25656753',
#   'pos': [-31.9842443, 115.7779675],
#   'type': 'node'},
#  {'created': {'changeset': '12726002',
#    'timestamp': '2012-08-14T11:59:12Z',
#    'uid': '142807',
#    'user': 'SDavies',
#    'version': '3'},
#   'id': '25656754',
#   'pos': [-31.9846468, 115.7782574],
#   'type': 'node'},
#  {'created': {'changeset': '3222714',
#    'timestamp': '2009-11-26T19:15:23Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '3'},
#   'id': '25656756',
#   'pos': [-31.9838841, 115.7764459],
#   'type': 'node'},
#  {'created': {'changeset': '12327812',
#    'timestamp': '2012-07-19T13:02:50Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '3'},
#   'id': '25656758',
#   'pos': [-31.9851692, 115.7754648],
#   'type': 'node'},
#  {'created': {'changeset': '3222714',
#    'timestamp': '2009-11-26T19:15:12Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656763',
#   'pos': [-31.9853754, 115.7756292],
#   'type': 'node'},
#  {'created': {'changeset': '3222714',
#    'timestamp': '2009-11-26T19:15:12Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656764',
#   'pos': [-31.9855403, 115.7756708],
#   'type': 'node'},
#  {'created': {'changeset': '3222714',
#    'timestamp': '2009-11-26T19:15:03Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656765',
#   'pos': [-31.9865709, 115.7756493],
#   'type': 'node'},
#  {'created': {'changeset': '3222714',
#    'timestamp': '2009-11-26T19:15:22Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656766',
#   'pos': [-31.9839171, 115.7754549],
#   'type': 'node'},
#  {'created': {'changeset': '3740723',
#    'timestamp': '2010-01-29T04:34:12Z',
#    'uid': '84853',
#    'user': 'mdp553',
#    'version': '3'},
#   'id': '25656767',
#   'pos': [-31.9860668, 115.7731443],
#   'type': 'node'},
#  {'created': {'changeset': '3222714',
#    'timestamp': '2009-11-26T19:15:43Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656768',
#   'pos': [-31.9858315, 115.7736538],
#   'type': 'node'},
#  {'created': {'changeset': '3740723',
#    'timestamp': '2010-01-29T04:34:12Z',
#    'uid': '84853',
#    'user': 'mdp553',
#    'version': '2'},
#   'id': '25656770',
#   'pos': [-31.9866093, 115.771922],
#   'type': 'node'},
#  {'created': {'changeset': '3220556',
#    'timestamp': '2009-11-26T14:17:15Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656771',
#   'pos': [-31.9863316, 115.771898],
#   'type': 'node'},
#  {'created': {'changeset': '3220556',
#    'timestamp': '2009-11-26T14:17:15Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656772',
#   'pos': [-31.9863202, 115.7716566],
#   'type': 'node'},
#  {'created': {'changeset': '3740723',
#    'timestamp': '2010-01-29T04:34:12Z',
#    'uid': '84853',
#    'user': 'mdp553',
#    'version': '2'},
#   'id': '25656773',
#   'pos': [-31.9870739, 115.7709247],
#   'type': 'node'},
#  {'created': {'changeset': '3740723',
#    'timestamp': '2010-01-29T04:34:12Z',
#    'uid': '84853',
#    'user': 'mdp553',
#    'version': '2'},
#   'id': '25656774',
#   'pos': [-31.9875657, 115.7700995],
#   'type': 'node'},
#  {'created': {'changeset': '3220556',
#    'timestamp': '2009-11-26T14:17:22Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656775',
#   'pos': [-31.9878991, 115.7695042],
#   'type': 'node'},
#  {'created': {'changeset': '3220556',
#    'timestamp': '2009-11-26T14:17:08Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '3'},
#   'id': '25656776',
#   'pos': [-31.9880094, 115.769362],
#   'type': 'node'},
#  {'created': {'changeset': '3773013',
#    'timestamp': '2010-02-02T01:40:49Z',
#    'uid': '84853',
#    'user': 'mdp553',
#    'version': '2'},
#   'id': '25656777',
#   'pos': [-31.988932, 115.7686439],
#   'type': 'node'},
#  {'created': {'changeset': '3429128',
#    'timestamp': '2009-12-22T17:56:45Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '3'},
#   'id': '25656778',
#   'pos': [-31.9897097, 115.7645699],
#   'type': 'node'},
#  {'created': {'changeset': '3220556',
#    'timestamp': '2009-11-26T14:17:02Z',
#    'uid': '9060',
#    'user': 'TRS-80',
#    'version': '2'},
#   'id': '25656779',
#   'pos': [-31.9897042, 115.7656445],
#   'type': 'node'},
#  ...]
